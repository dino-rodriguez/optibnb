# %% [markdown]
# ### Import Libaries:

# %%
import numpy as np
import pandas as pd
import scipy as sp
from datetime import datetime
from scipy.stats import mode
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.linear_model import RidgeCV
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
import matplotlib
import matplotlib.pyplot as plt
from sklearn import discriminant_analysis
from sklearn.decomposition import PCA
from sklearn import preprocessing
from collections import Counter
# %matplotlib inline

# %%
# Global variables
BNB_BLUE = '#007A87'
BNB_RED = '#FF5A5F'
BNB_DARK_GRAY = '#565A5C'
BNB_LIGHT_GRAY = '#CED1CC'

# %% [markdown]
# ### Import listings, clean data, extract features

# %%
# Read in the data 
listings = pd.read_csv('listings_Jan.csv', delimiter=',')
calendar = pd.read_csv('calendar_Jan.csv', delimiter=',')

# View feature list
print listings.columns.values
# Out:
# ['id' 'scrape_id' 'last_scraped' 'name' 'picture_url' 'host_id' 'host_name'
#  'host_since' 'host_picture_url' 'street' 'neighbourhood'
#  'neighbourhood_cleansed' 'city' 'state' 'zipcode' 'market' 'country'
#  'latitude' 'longitude' 'is_location_exact' 'property_type' 'room_type'
#  'accommodates' 'bathrooms' 'bedrooms' 'beds' 'bed_type' 'square_feet'
#  'price' 'weekly_price' 'monthly_price' 'guests_included' 'extra_people'
#  'minimum_nights' 'maximum_nights' 'calendar_updated' 'availability_30'
#  'availability_60' 'availability_90' 'availability_365'
#  'calendar_last_scraped' 'number_of_reviews' 'first_review' 'last_review'
#  'review_scores_rating' 'review_scores_accuracy'
#  'review_scores_cleanliness' 'review_scores_checkin'
#  'review_scores_communication' 'review_scores_location'
#  'review_scores_value' 'host_listing_count']

# %%
subway_distance = pd.read_csv('transit_location.csv', delimiter = ',')

# %%
# Unsuppress Output
pd.options.display.max_columns = 70

# Split into predictor and response
y = listings[['price']]
x = listings
del x['price']
x = x.join(y)


# Show predictor df
print 'Predictor Data Shape: ', x.shape
x.head(n = 3)
# Out:
# Predictor Data Shape:  (27392, 52)
#         id     scrape_id last_scraped                                 name  \
# 0  1069266  2.015010e+13       1/2/15        Stay like a real New Yorker!
# 1  1846722  2.015010e+13       1/2/15    Apartment 20 Minutes Times Square
# 2  2061725  2.015010e+13       1/2/15  Option of 2 Beds w Private Bathroom
#
#                                          picture_url  host_id host_name  \
# 0  https://a0.muscache.com/pictures/50276484/larg...  5867023   Michael
# 1  https://a1.muscache.com/pictures/35865039/larg...  2631556    Denise
# 2  https://a2.muscache.com/pictures/50650147/larg...  4601412      Miao
#
#   host_since                                   host_picture_url  \
# 0    4/10/13  https://a2.muscache.com/ic/users/5867023/profi...
# 1    6/13/12  https://a2.muscache.com/ic/users/2631556/profi...
# 2     1/5/13  https://a0.muscache.com/ic/users/4601412/profi...
#
#                                               street     neighbourhood  \
# 0  East 53rd Street, New York, NY 10022, United S...      Midtown East
# 1     West 155th Street, New York, NY, United States  Hamilton Heights
# 2  Van Buren Street, Brooklyn, NY 11221, United S...          Bushwick
#
#   neighbourhood_cleansed      city state zipcode    market        country  \
# 0           Midtown East  New York    NY   10022  New York  United States
# 1       Hamilton Heights  New York    NY     NaN  New York  United States
# 2               Bushwick  Brooklyn    NY   11221  New York  United States
#
#     latitude  longitude is_location_exact property_type        room_type  \
# 0  40.756852 -73.964754                 t     Apartment  Entire home/apt
# 1  40.830599 -73.941014                 f     Apartment  Entire home/apt
# 2  40.692189 -73.924120                 t     Apartment     Private room
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  square_feet  \
# 0             2        1.0       1.0   1.0  Real Bed          NaN
# 1            10        1.0       3.0   3.0  Real Bed          NaN
# 2             2        1.0       1.0   2.0  Real Bed          NaN
#
#   weekly_price monthly_price  guests_included extra_people  minimum_nights  \
# 0   $1,000.00            NaN                2       $0.00                3
# 1          NaN           NaN                1      $50.00                1
# 2          NaN           NaN                1      $12.00                3
#
#    maximum_nights calendar_updated  availability_30  availability_60  \
# 0              14      3 weeks ago               21               51
# 1             180       4 days ago               28               58
# 2              30            today                4               13
#
#    availability_90  availability_365 calendar_last_scraped  number_of_reviews  \
# 0               72               322                1/2/15                 62
# 1               88               348                1/2/15                 22
# 2               26               227                1/2/15                 35
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0      4/28/13    12/17/14                  86.0                     9.0
# 1       1/5/14    12/29/14                  85.0                     8.0
# 2       2/4/14    12/29/14                  98.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        7.0                    9.0
# 1                        8.0                    9.0
# 2                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          9.0                    10.0                  9.0
# 1                          8.0                     7.0                  8.0
# 2                         10.0                     9.0                 10.0
#
#    host_listing_count     price
# 0                   1  $160.00
# 1                   2  $105.00
# 2                   4   $58.00

# %% [markdown]
# For our baseline model, we can start by removing features that we intuitively sense will not impact a listing's price. This includes 11 features.

# %%
del x['scrape_id']
del x['last_scraped'] # all within first three days of January, not necessary feature
del x['picture_url']
del x['host_picture_url']
del x['neighbourhood'] # neighbourhood_cleansed is in a better format
del x['state'] # all NY
del x['market'] # all New York
del x['country'] # all United States
del x['weekly_price'] # function of daily price
del x['monthly_price'] # function of daily price
del x['calendar_last_scraped'] # all within first three days of January, not necessary feature

print 'Predictor Data Shape: ', x.shape
# Out:
# Predictor Data Shape:  (27392, 41)

# %%
# Returns percent of missing data in column
def percent_empty(df):
    bools = df.isnull().tolist()
    percent_empty = float(bools.count(True)) / float(len(bools))
    return percent_empty

emptiness = []

for i in range(0, x.shape[1]):
    emptiness.append(round(percent_empty(x.iloc[:,i]),2))
    
empty_dict = dict(zip(x.columns.values.tolist(), emptiness))

empty = pd.DataFrame.from_dict(empty_dict, orient = 'index').sort_values(by=0)
ax = empty.plot(kind='bar',color='red', figsize = (16, 5))
ax.set_xlabel('Predictor')
ax.set_ylabel('Percent Empty/NaN')
ax.set_title('Feature Emptiness')
ax.legend_.remove()
plt.show()

# %%
del x['square_feet'] #remove it because it has too many missing values

# %%
bedrooms_counts = Counter(x.bedrooms)
tdf = pd.DataFrame.from_dict(bedrooms_counts, orient='index').sort_values(by=0)
tdf = tdf.iloc[-10:, :] / 27392

print tdf

ax = tdf.plot(kind='bar', figsize = (12,4))
ax.set_xlabel("# of Bedrooms")
ax.set_ylabel("% of Listings")
ax.set_title('Percent of Listings by Bedrooms #')
ax.legend_.remove()

plt.show()
# Out:
#              0
# 10.0  0.000146
# 8.0   0.000183
# 7.0   0.000183
# 6.0   0.000511
# 5.0   0.001679
# 4.0   0.006608
# 3.0   0.030155
# 0.0   0.085353
# 2.0   0.126935
# 1.0   0.743100

# %% [markdown]
# Let's remove entries (rows) that have faulty data like when
# - There are 0 bedrooms
# - There are 0 bathrooms
# - There are 0 beds
# - The price is $0

# %%
# Delete bad entries
x = x[x.bedrooms != 0]
x = x[x.beds != 0]
x = x[x.bathrooms != 0]
x = x[x.price != 0]

# Delete additional entries with NaN values
x = x.dropna(axis=0)

print 'Size of trimmed data: ', x.shape
# Out:
# Size of trimmed data:  (16446, 40)

# %% [markdown]
# We also need to drop the dollar sign from our price and turn the type into a float.

# %%
# Convert $ to float for 'price'
x['price'] = x['price'].replace('[\$,)]','',  \
        regex=True).replace('[(]','-', regex=True).astype(float)

# Convert $ to float for 'extra people'
x['extra_people'] = x['extra_people'].replace('[\$,)]','',  \
        regex=True).replace('[(]','-', regex=True).astype(float)

# %%
zero_fivehundred = x[x['price'] < 500]
five_thousand = x[(x['price'] > 500) & (x['price'] < 1000)]
thousand_fifteen = x[(x['price'] > 1000) & (x['price'] < 1500)]
fifteen_three = x[(x['price'] > 1500) & (x['price'] < 3000)]
three_four = x[(x['price'] > 3000) & (x['price'] < 4000)]
four_five = x[(x['price'] > 4000) & (x['price'] < 5000)]

# Let's get a feel for our data
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2,3, figsize = (16,9))

BINS = 10

ax1.hist(zero_fivehundred['price'], bins=BINS)
ax1.set_xlabel('Listings Priced 0 to 500')
ax2.hist(five_thousand['price'], bins=BINS)
ax2.set_xlabel('Listings Priced 500 to 1000')
ax3.hist(thousand_fifteen['price'], bins=BINS)
ax3.set_xlabel('Listings Priced 1000 to 1500')
ax4.hist(fifteen_three['price'], bins=BINS)
ax4.set_xlabel('Listings Priced 1500 to 3000')
ax5.hist(three_four['price'], bins=BINS)
ax5.set_xlabel('Listings Priced 3000 to 4000')
ax6.hist(four_five['price'], bins=BINS)
ax6.set_xlabel('Listings Priced 4000 to 5000')


plt.show()

# %% [markdown]
# For a map visualization, say we want generally even sized buckets, each of which will map to a color. By looking at our histograms let's have our buckets the intervals of [0,50,100,150,250,500,10000].

# %%
# Outline price buckets
intervals = [0,100,300,10000]
leg_labels = []

# Get Labels for Legend
for i in range(0,len(intervals) - 1):
    if i == len(intervals) - 2:
        leg_labels.append('\${}+'.format(intervals[i]))
    else:
        leg_labels.append("\${}-\${}".format(intervals[i], intervals[i+1]))    

buckets = []

# Divide up into buckets
for i in range(0, len(intervals) - 1):
    buckets.append(x[(x['price'] > intervals[i]) & (x['price'] < intervals[i+1])])

colors = ['red', 'blue', 'yellow', 'cyan', 'cyan', 'purple']
alphas = [.3,.2,.5,1,.4,.2]  

# Plot listings on scatter
plt.figure(figsize=(15, 15))
for i in range(0, len(buckets)):
    plt.scatter(buckets[i]['latitude'], buckets[i]['longitude'], alpha = alphas[i], c=colors[i], s=25)
    
plt.title('New York City - AirBnB Listings')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.legend(labels=leg_labels, loc = 'best')
plt.ylim(-74.2,-73.7)
plt.xlim(40.45,40.95)

plt.show()

# %%
# encode_categorical
# 
# Function to label encode categorical variables.
#     Input: array (array of values)
#     Output: array (array of encoded values)
def encode_categorical(array):
    if not array.dtype == np.dtype('float64'):
        return preprocessing.LabelEncoder().fit_transform(array) 
    else:
        return array

new_x = x.apply(encode_categorical)

# %%
# Compute matrix of correlation coefficients
corr_matrix = np.corrcoef(new_x.T)

pd.DataFrame(data = corr_matrix, columns = new_x.columns, index = new_x.columns)
# Out:
#                                    id      name   host_id  host_name  \
# id                           1.000000  0.003586  0.636400  -0.011425
# name                         0.003586  1.000000 -0.005514   0.011629
# host_id                      0.636400 -0.005514  1.000000  -0.003635
# host_name                   -0.011425  0.011629 -0.003635   1.000000
# host_since                   0.063344  0.012767  0.061164   0.002260
# street                       0.001867  0.003640 -0.001452  -0.025501
# neighbourhood_cleansed      -0.026670  0.053067 -0.011103  -0.027789
# city                         0.003935 -0.022167  0.051583  -0.013907
# zipcode                      0.023209  0.023011 -0.008090   0.015409
# latitude                     0.014481 -0.010866  0.070719  -0.014152
# longitude                    0.060216  0.006946  0.072403   0.025964
# is_location_exact           -0.115502 -0.005011 -0.092881  -0.006841
# property_type               -0.017178  0.028221 -0.024100   0.010808
# room_type                    0.108725  0.069977  0.074776   0.014016
# accommodates                 0.000199 -0.047654 -0.022126   0.017474
# bathrooms                    0.023057  0.007498 -0.001915   0.010488
# bedrooms                    -0.005512 -0.058100 -0.011524   0.003384
# beds                         0.016565 -0.022017 -0.010190   0.032774
# bed_type                    -0.010546 -0.003205 -0.011209   0.003541
# guests_included             -0.083786 -0.042594 -0.069633   0.000677
# extra_people                -0.113227 -0.005332 -0.087431   0.006414
# minimum_nights              -0.187060 -0.016841 -0.143581   0.018112
# maximum_nights               0.266313  0.016549  0.163782   0.006002
# calendar_updated             0.029563 -0.003551  0.018176   0.018750
# availability_30             -0.012517  0.015437  0.011865   0.019972
# availability_60             -0.031551  0.016648  0.000110   0.022003
# availability_90             -0.041107  0.016697 -0.008262   0.022456
# availability_365            -0.062867  0.016186 -0.025864   0.020227
# number_of_reviews           -0.464808  0.012132 -0.307188   0.002312
# first_review                -0.044874  0.020033 -0.017941  -0.008215
# last_review                 -0.076762  0.002202 -0.049587   0.008509
# review_scores_rating        -0.039905  0.002375 -0.036938  -0.010690
# review_scores_accuracy       0.008138  0.007452  0.000419  -0.017883
# review_scores_cleanliness    0.010157  0.009518  0.005808   0.004840
# review_scores_checkin       -0.045419 -0.002886 -0.020963  -0.008539
# review_scores_communication -0.036229 -0.005777 -0.023677  -0.010220
# review_scores_location      -0.043225 -0.003903 -0.039562  -0.024263
# review_scores_value          0.012443 -0.000530  0.011106  -0.017133
# host_listing_count           0.013762  0.041149 -0.085388   0.042281
# price                       -0.048688 -0.036518 -0.043286  -0.014688
#
#                              host_since    street  neighbourhood_cleansed  \
# id                             0.063344  0.001867               -0.026670
# name                           0.012767  0.003640                0.053067
# host_id                        0.061164 -0.001452               -0.011103
# host_name                      0.002260 -0.025501               -0.027789
# host_since                     1.000000 -0.017007               -0.010858
# street                        -0.017007  1.000000                0.129405
# neighbourhood_cleansed        -0.010858  0.129405                1.000000
# city                          -0.009547  0.042858                0.112791
# zipcode                        0.021148 -0.160312               -0.072033
# latitude                       0.011841  0.180803                0.231772
# longitude                           0.061316         0.070412
# is_location_exact                  -0.030972        -0.032899
# property_type                       0.065388         0.077598
# room_type                           0.146348         0.160836
# accommodates                        0.043014         0.039129
# bathrooms                           0.014571         0.013371
# bedrooms                           -0.017343        -0.020464
# beds                                0.049241         0.047125
# bed_type                           -0.035369        -0.040377
# guests_included                     0.018138         0.020296
# extra_people                        0.095072         0.100446
# minimum_nights                     -0.102421        -0.102741
# maximum_nights                     -0.023368        -0.027027
# calendar_updated                    0.030362         0.038589
# availability_30                     1.000000         0.926748
# availability_60                     0.926748         1.000000
# availability_90                     0.864153         0.973454
# availability_365                    0.615315         0.730890
# number_of_reviews                   0.067424         0.094629
# first_review                       -0.005679        -0.012829
# last_review                        -0.151216        -0.158337
# review_scores_rating               -0.076059        -0.077901
# review_scores_accuracy             -0.088471        -0.090190
# review_scores_cleanliness          -0.027676        -0.022865
# review_scores_checkin              -0.038126        -0.036954
# review_scores_communication        -0.050451        -0.052428
# review_scores_location             -0.077552        -0.082902
# review_scores_value                -0.097179        -0.101164
# host_listing_count                  0.131215         0.145120
# price                               0.026038         0.020173
#
#                              availability_90  availability_365  \
# id                                 -0.041107         -0.062867
# name                                0.016697          0.016186
# host_id                            -0.008262         -0.025864
# host_name                           0.022456          0.020227
# host_since                         -0.011614         -0.006311
# street                             -0.019157         -0.027208
# neighbourhood_cleansed             -0.040152         -0.040760
# city                               -0.007792         -0.046013
# zipcode                             0.048286          0.087185
# latitude                           -0.013171         -0.040331
# longitude                           0.078072          0.093218
# is_location_exact                  -0.033989         -0.030449
# property_type                       0.083282          0.084669
# room_type                           0.170820          0.166322
# accommodates                        0.033267          0.008250
# bathrooms                           0.011402          0.007688
# bedrooms                           -0.023560         -0.023295
# beds                                0.044359          0.032996
# bed_type                           -0.040710         -0.026435
# guests_included                     0.016795          0.006911
# extra_people                        0.103588          0.089890
# minimum_nights                     -0.102213         -0.078545
# maximum_nights                     -0.023723         -0.008449
# calendar_updated                    0.038182          0.022184
# availability_30                     0.864153          0.615315
# availability_60                     0.973454          0.730890
# availability_90                     1.000000          0.795709
# availability_365                    0.795709          1.000000
# number_of_reviews                   0.101348          0.073450
# first_review                       -0.017049          0.011280
# last_review                        -0.158595         -0.092408
# review_scores_rating               -0.079596         -0.086165
# review_scores_accuracy             -0.093522         -0.099259
# review_scores_cleanliness          -0.022045         -0.034106
# review_scores_checkin              -0.038292         -0.051246
# review_scores_communication        -0.054718         -0.064147
# review_scores_location             -0.087255         -0.103060
# review_scores_value                -0.104404         -0.109317
# host_listing_count                  0.158241          0.157458
# price                               0.016078          0.005590
#
#                              number_of_reviews  first_review  last_review  \
# id                                   -0.464808     -0.044874    -0.076762
# name                                  0.012132      0.020033     0.002202
# host_id                              -0.307188     -0.017941    -0.049587
# host_name                             0.002312     -0.008215     0.008509
# host_since                           -0.017534      0.137987     0.003607
# street                               -0.008318      0.002142     0.003955
# neighbourhood_cleansed                0.000729      0.008523    -0.002461
# city                                  0.032676     -0.016149    -0.023284
# zipcode                              -0.038348      0.016840     0.023939
# latitude                              0.027650      0.001558    -0.025499
# longitude                            -0.013442      0.011400    -0.005381
# is_location_exact                     0.041990      0.010936     0.021032
# property_type                         0.035009      0.018508    -0.023717
# room_type                             0.025381      0.019751    -0.032533
# accommodates                          0.034431     -0.023872    -0.023800
# bathrooms                            -0.042990      0.002666     0.014892
# bedrooms                             -0.024284     -0.010044     0.031341
# beds                                  0.008352     -0.005084    -0.005485
# bed_type                             -0.013107     -0.014512     0.014133
# guests_included                       0.062978     -0.012814    -0.018709
# extra_people                          0.061701      0.002636    -0.030483
# minimum_nights                       -0.064623      0.009577     0.085873
# maximum_nights                       -0.113564     -0.015388    -0.007965
# calendar_updated                      0.137969     -0.004174    -0.047758
# availability_30                       0.067424     -0.005679    -0.151216
# availability_60                       0.094629     -0.012829    -0.158337
# availability_90                       0.101348     -0.017049    -0.158595
# availability_365                      0.073450      0.011280    -0.092408
# number_of_reviews                     1.000000      0.010146    -0.128973
# first_review                          0.010146      1.000000     0.194917
# last_review                          -0.128973      0.194917     1.000000
# review_scores_rating                 -0.010069     -0.015620     0.004799
# review_scores_accuracy               -0.021541     -0.011375    -0.003346
# review_scores_cleanliness             0.015023     -0.015367    -0.029392
# review_scores_checkin                 0.031651     -0.009154    -0.014845
# review_scores_communication           0.002021      0.000961    -0.003122
# review_scores_location               -0.000959     -0.013984    -0.001468
# review_scores_value                  -0.006253     -0.026661     0.002899
# host_listing_count                    0.050972     -0.018616    -0.052555
# price                                -0.055742     -0.010557     0.016494
#
#                              review_scores_rating  review_scores_accuracy  \
# id                                      -0.039905                0.008138
# name                                     0.002375                0.007452
# host_id                                 -0.036938                0.000419
# host_name                               -0.010690               -0.017883
# host_since                              -0.000214               -0.001694
# street                                   0.027079                0.028647
# neighbourhood_cleansed                   0.044419                0.023857
# city                                    -0.024309               -0.031633
# zipcode                                  0.015729                0.025462
# latitude                                -0.007391               -0.005799
# longitude                               -0.039792               -0.013053
# is_location_exact                        0.035939                0.035035
# property_type                           -0.011481               -0.030394
# room_type                               -0.076667               -0.107991
# accommodates                            -0.080336               -0.069738
# bathrooms                               -0.000683               -0.021149
# bedrooms                                -0.018654               -0.019519
# beds                                    -0.101125               -0.101740
# bed_type                                -0.003254               -0.003219
# guests_included                         -0.015480               -0.006670
# extra_people                             0.002726               -0.015487
# minimum_nights                           0.033680                0.022118
# maximum_nights                          -0.070033               -0.057579
# calendar_updated                        -0.014023               -0.005014
# availability_30                         -0.076059               -0.088471
# availability_60                         -0.077901               -0.090190
# availability_90                         -0.079596               -0.093522
# availability_365                        -0.086165               -0.099259
# number_of_reviews                       -0.010069               -0.021541
# first_review                            -0.015620               -0.011375
# last_review                              0.004799               -0.003346
# review_scores_rating                     1.000000                0.651980
# review_scores_accuracy                   0.651980                1.000000
# review_scores_cleanliness                0.674777                0.557079
# review_scores_checkin                    0.559572                0.435166
# review_scores_communication              0.557208                0.429930
# review_scores_location                   0.419567                0.300281
# review_scores_value                      0.701255                0.585271
# host_listing_count                      -0.201666               -0.197635
# price                                    0.086060                0.066242
#
#                              review_scores_cleanliness  review_scores_checkin  \
# id                                            0.010157              -0.045419
# name                                          0.009518              -0.002886
# host_id                                       0.005808              -0.020963
# host_name                                     0.004840              -0.008539
# host_since                                    0.004602              -0.003439
# street                                        0.017022               0.004240
# neighbourhood_cleansed                        0.014428               0.015556
# city                                         -0.030259              -0.028346
# zipcode                                       0.042031               0.028410
# latitude                                     -0.013741              -0.019853
# longitude                                     0.009287              -0.009062
# is_location_exact                             0.002867               0.022915
# property_type                                 0.005847              -0.002537
# room_type                                    -0.084662              -0.044229
# accommodates                                 -0.027073              -0.065301
# bathrooms                                    -0.008599              -0.017358
# bedrooms                                      0.010795              -0.015398
# beds                                         -0.055999              -0.066340
# bed_type                                     -0.013368              -0.018086
# guests_included                               0.020688              -0.007629
# extra_people                                  0.021414               0.005210
# minimum_nights                                0.011056               0.010743
# maximum_nights                               -0.066237              -0.071247
# calendar_updated                              0.008548              -0.009530
# availability_30                              -0.027676              -0.038126
# availability_60                              -0.022865              -0.036954
# availability_90                              -0.022045              -0.038292
# availability_365                             -0.034106              -0.051246
# number_of_reviews                             0.015023               0.031651
# first_review                                 -0.015367              -0.009154
# last_review                                  -0.029392              -0.014845
# review_scores_rating                          0.674777               0.559572
# review_scores_accuracy                        0.557079               0.435166
# review_scores_cleanliness                     1.000000               0.423995
# review_scores_checkin                         0.423995               1.000000
# review_scores_communication                   0.407577               0.600902
# review_scores_location                        0.259666               0.267609
# review_scores_value                           0.566751               0.464587
# host_listing_count                           -0.126405              -0.154155
# price                                         0.072085               0.035227
#
#                              review_scores_communication  \
# id                                             -0.036229
# name                                           -0.005777
# host_id                                        -0.023677
# host_name                                      -0.010220
# host_since                                     -0.004722
# street                                          0.012008
# neighbourhood_cleansed                          0.024566
# city                                           -0.028694
# zipcode                                         0.009053
# latitude                                       -0.009376
# longitude                                      -0.033093
# is_location_exact                               0.016598
# property_type                                  -0.014342
# room_type                                      -0.058465
# accommodates                                   -0.069338
# bathrooms                                      -0.028620
# bedrooms                                       -0.030229
# beds                                           -0.074540
# bed_type                                       -0.013574
# guests_included                                -0.007335
# extra_people                                    0.009610
# minimum_nights                                  0.008540
# maximum_nights                                 -0.063363
# calendar_updated                               -0.003650
# availability_30                                -0.050451
# availability_60                                -0.052428
# availability_90                                -0.054718
# availability_365                               -0.064147
# number_of_reviews                               0.002021
# first_review                                    0.000961
# last_review                                    -0.003122
# review_scores_rating                            0.557208
# review_scores_accuracy                          0.429930
# review_scores_cleanliness                       0.407577
# review_scores_checkin                           0.600902
# review_scores_communication                     1.000000
# review_scores_location                          0.284680
# review_scores_value                             0.457625
# host_listing_count                             -0.166236
# price                                           0.042248
#
#                              review_scores_location  review_scores_value  \
# id                                        -0.043225             0.012443
# name                                      -0.003903            -0.000530
# host_id                                   -0.039562             0.011106
# host_name                                 -0.024263            -0.017133
# host_since                                -0.025905            -0.001612
# street                                     0.054589             0.021066
# neighbourhood_cleansed                     0.213497             0.026509
# city                                       0.173782            -0.024610
# zipcode                                   -0.225166             0.034674
# latitude                                   0.049380            -0.000980
# longitude                                 -0.324439            -0.005737
# is_location_exact                          0.003605             0.026787
# property_type                             -0.103296            -0.012092
# room_type                                 -0.126362            -0.027806
# accommodates                              -0.084879            -0.072627
# bathrooms                                 -0.026542            -0.006660
# bedrooms                                  -0.025322            -0.021427
# beds                                      -0.098172            -0.079958
# bed_type                                   0.005207            -0.012691
# guests_included                           -0.037843            -0.028816
# extra_people                               0.025289            -0.028236
# minimum_nights                             0.024297             0.022015
# maximum_nights                            -0.021012            -0.049960
# calendar_updated                          -0.010537            -0.001975
# availability_30                           -0.077552            -0.097179
# availability_60                           -0.082902            -0.101164
# availability_90                           -0.087255            -0.104404
# availability_365                          -0.103060            -0.109317
# number_of_reviews                         -0.000959            -0.006253
# first_review                              -0.013984            -0.026661
# last_review                               -0.001468             0.002899
# review_scores_rating                       0.419567             0.701255
# review_scores_accuracy                     0.300281             0.585271
# review_scores_cleanliness                  0.259666             0.566751
# review_scores_checkin                      0.267609             0.464587
# review_scores_communication                0.284680             0.457625
# review_scores_location                     1.000000             0.394526
# review_scores_value                        0.394526             1.000000
# host_listing_count                        -0.195557            -0.138622
# price                                      0.192117             0.013132
#
#                              host_listing_count     price
# id                                     0.013762 -0.048688
# name                                   0.041149 -0.036518
# host_id                               -0.085388 -0.043286
# host_name                              0.042281 -0.014688
# host_since                            -0.010573 -0.010061
# street                                -0.066054  0.065723
# neighbourhood_cleansed                -0.075486  0.084506
# city                                  -0.069250  0.159646
# zipcode                                0.102507 -0.238596
# latitude                              -0.067770  0.035865
# longitude                              0.102907 -0.270796
# is_location_exact                      0.013777 -0.002902
# property_type                          0.157808  0.023131
# room_type                              0.236034 -0.438484
# accommodates                           0.186567  0.436370
# bathrooms                              0.143835  0.324165
# bedrooms                               0.021974  0.492907
# beds                                   0.273227  0.300251
# bed_type                               0.029214  0.093067
# guests_included                        0.042922  0.324036
# extra_people                           0.034671  0.108305
# minimum_nights                        -0.041753  0.022208
# maximum_nights                         0.109890  0.014326
# calendar_updated                       0.065605 -0.008582
# availability_30                        0.131215  0.026038
# availability_60                        0.145120  0.020173
# availability_90                        0.158241  0.016078
# availability_365                       0.157458  0.005590
# number_of_reviews                      0.050972 -0.055742
# first_review                          -0.018616 -0.010557
# last_review                           -0.052555  0.016494
# review_scores_rating                  -0.201666  0.086060
# review_scores_accuracy                -0.197635  0.066242
# review_scores_cleanliness             -0.126405  0.072085
# review_scores_checkin                 -0.154155  0.035227
# review_scores_communication           -0.166236  0.042248
# review_scores_location                -0.195557  0.192117
# review_scores_value                   -0.138622  0.013132
# host_listing_count                     1.000000 -0.086563
# price                                 -0.086563  1.000000

# %%
# Compute matrix of correlation coefficients
corr_matrix = np.corrcoef(new_x.T)

# Display heat map 
plt.figure(figsize=(7, 7))
plt.pcolor(corr_matrix, cmap='RdBu')
plt.xlabel('Predictor Index')
plt.ylabel('Predictor Index')
plt.title('Heatmap of Correlation Matrix')
plt.colorbar()

plt.show()

# %% [markdown]
# We notice that there is a high correlation between all of the availability features. Availability 365 has the lowest correlation to the others, so opt to keep it.

# %%
del new_x['availability_30']
del new_x['availability_60']
del new_x['availability_90']

# %% [markdown]
# Because we are doing OLS for our baseline regression, we must have only numerical predictors and so we must also one-hot encode our categorical variables. We also get rid of a number of the categorical variables that have too many unique combinations when one-hot encoded.

# %%
del new_x['id']
del new_x['host_id']
del new_x['host_name']
del new_x['street']
del new_x['name']

# %%
# Apply one hot endcoing
#categorical = (new_x.dtypes.values != np.dtype('float64'))

#encoder = preprocessing.OneHotEncoder(categorical_features = categorical, sparse = False)  # Last value in mask is y
#new_x = encoder.fit_transform(new_x)

# %%
#print new_x.shape

# %% [markdown]
# We can see that one-hot encoding brought our number of features from 13 to 197. In actuality and as a quick sanity check, the only categorical variables are 'property_type', 'room_type', and 'neighbourhood_cleansed' and there are 186 neighbourhoods so this makes sense.

# %%
new_x['distance_to_subway'] = subway_distance['distance_to_subway']
new_x
# Out:
#        host_since  neighbourhood_cleansed  city  zipcode   latitude  \
# 0             968                      99    66       21  40.756852
# 2             124                      19    18      112  40.692189
# 3            1614                     159    66       12  40.734751
# 4             183                      23    66       12  40.745282
# 5               9                      21    18      121  40.679060
# 8             534                      49    66        2  40.726022
# 9             785                       9    18      112  40.686420
# 12           1280                      98    66       18  40.751129
# 13            430                      40    18      104  40.667790
# 14           1598                     144    66       19  40.760679
# 15            429                     159    66       15  40.735109
# 16           1532                      49    66        2  40.733285
# 17            152                     157    66       39  40.862270
# 18            938                     157    66       32  40.847966
# 19            642                      40    18      128  40.670997
# 20           1345                      54    66       37  40.706879
# 21           1887                      72    66       26  40.806526
# 22            234                      68    18      113  40.726067
# 24            860                     153    66       24  40.799322
# 26             50                      72    66       29  40.813161
# 28            543                      69    66        2  40.734000
# 30            638                      26    66       37  40.711173
# 32             56                      49    66        9  40.730210
# 33           1706                      71    66       30  40.824909
# 35            993                      72    66       25  40.801176
# 36            925                      72    66       26  40.810943
# 39            983                      72    66       29  40.819045
# 44            324                     152    66       46  40.779685
# 45           1125                       2    54       85  40.756194
# 47           1896                      71    66       30  40.823221
# ...           ...                     ...   ...      ...        ...
# 27356         977                     164    18      102  40.713552
# 27357        1841                       2    78       90  40.759992
# 27358          50                      72    66       26  40.814941
# 27359        1598                      23    66       12  40.742466
# 27360        1180                      19    18      112  40.700403
# 27361        1810                      64    66        2  40.736810
# 27362        1717                     164    18      127  40.704424
# 27363         392                     152    66       42  40.764169
# 27364        1117                       2    78      145  40.758450
# 27365        1275                      17    18       93  40.693113
# 27366        1472                       2     5       86  40.766327
# 27367        1634                      12    18       93  40.688960
# 27370        1114                      29    18      128  40.684129
# 27371        1820                     115    18      106  40.672742
# 27372         664                     164    18      102  40.710771
# 27373        1917                     164    18      102  40.713895
# 27374         428                     164    18      113  40.728677
# 27375         634                     164    18      102  40.711698
# 27376        1309                     164    18      102  40.714263
# 27377        1335                     164    18      102  40.716748
# 27379         119                     164    18      102  40.707842
# 27381         977                     164    18      102  40.711472
# 27382        1195                     164    18      102  40.710081
# 27383         803                     164    18      102  40.717938
# 27385         859                       9    18      123  40.681716
# 27386         854                      49    66        2  40.726843
# 27388         992                     144    66       19  40.759642
# 27389        1331                     136    94       51  40.645741
# 27390         550                      40    18      104  40.669931
# 27391        1346                      73    66       18  40.753941
#
#        longitude  is_location_exact  property_type  room_type  accommodates  \
# 0     -73.964754                  1              0          0             1
# 2     -73.924120                  1              0          1             1
# 3     -74.002592                  1              0          0             1
# 4     -73.997836                  1              0          0             1
# 5     -73.994730                  1              0          0             5
# 8     -73.986418                  1              0          0             3
# 9     -73.934402                  1              0          2             1
# 12    -73.985345                  1              0          2             3
# 13    -73.936787                  1              0          1             1
# 14    -73.984443                  1              0          0             2
# 15    -74.001821                  1              0          0             2
# 16    -73.984357                  1              0          1             0
# 17    -73.927017                  1              0          0             1
# 18    -73.930466                  1              0          2             0
# 19    -73.958107                  1              0          0             3
# 20    -74.005486                  1              0          1             1
# 21    -73.951936                  1              0          0             1
# 22    -73.951025                  1              0          1             0
# 24    -73.967679                  1              0          1             1
# 26    -73.949024                  1              0          0             9
# 28    -73.994491                  1              0          0             1
# 30    -74.006676                  1              0          0             2
# 32    -73.981450                  1              0          0             4
# 33    -73.951371                  1              0          1             3
# 35    -73.954510                  1              0          0             3
# 36    -73.950971                  1              0          1             1
# 39    -73.943253                  1              8          1             1
# 44    -73.953386                  1              0          0             3
# 45    -73.930050                  1              8          1             1
# 47    -73.955764                  1              0          1             1
# ...          ...                ...            ...        ...           ...
# 27356 -73.953047                  1              0          1             1
# 27357 -73.928813                  1              0          0             3
# 27358 -73.950380                  1              0          1             1
# 27359 -73.999037                  1              0          0             1
# 27360 -73.927122                  1             10          1             0
# 27361 -73.983665                  1              0          0             0
# 27362 -73.930097                  1              0          0             1
# 27363 -73.966191                  1              0          0             4
# 27364 -73.907712                  1              0          0             3
# 27365 -73.997592                  1              0          0             4
# 27366 -73.909589                  1              0          0             3
# 27367 -73.993769                  1              0          1             1
# 27370 -73.965424                  1              0          1             4
# 27371 -73.973390                  1              0          0             3
# 27372 -73.961455                  1              0          0             3
# 27373 -73.957778                  1             10          0             1
# 27374 -73.958348                  0              0          1             1
# 27375 -73.964070                  1              0          1             1
# 27376 -73.962187                  1              0          1             0
# 27377 -73.965086                  0             10          0             5
# 27379 -73.966361                  1             10          0             3
# 27381 -73.951097                  1              0          1             0
# 27382 -73.961231                  1              0          0             3
# 27383 -73.957785                  1              0          1             1
# 27385 -73.932360                  1              0          0             5
# 27386 -73.989648                  1              0          0             1
# 27388 -73.985343                  1              0          1             1
# 27389 -74.080955                  1              8          0             5
# 27390 -73.946820                  1              0          0             2
# 27391 -73.993232                  1              0          2             0
#
#        bathrooms  bedrooms  beds  bed_type  guests_included  extra_people  \
# 0            1.0       1.0   1.0         4                2           0.0
# 2            1.0       1.0   2.0         4                1          12.0
# 3            1.0       1.0   1.0         4                1           0.0
# 4            1.0       1.0   2.0         4                1           0.0
# 5            1.0       2.0   3.0         4                2          15.0
# 8            1.0       2.0   2.0         4                2          20.0
# 9            1.0       1.0   1.0         4                1          36.0
# 12           1.0       1.0   4.0         4                1          80.0
# 13           1.0       1.0   1.0         4                2          35.0
# 14           1.0       1.0   2.0         4                1           0.0
# 15           1.0       1.0   1.0         4                2          15.0
# 16           1.0       1.0   1.0         4                1           0.0
# 17           1.0       1.0   1.0         4                1           0.0
# 18           1.0       1.0   1.0         4                1           0.0
# 19           1.0       1.0   2.0         4                1          20.0
# 20           1.0       1.0   1.0         4                1          50.0
# 21           1.0       1.0   1.0         4                1           0.0
# 22           1.0       1.0   1.0         4                1          20.0
# 24           1.0       1.0   1.0         4                1           0.0
# 26           1.0       3.0   5.0         4                3          25.0
# 28           1.0       1.0   2.0         4                2           0.0
# 30           1.0       1.0   1.0         4                1           0.0
# 32           1.0       1.0   2.0         4                2          30.0
# 33           1.0       1.0   1.0         4                2          40.0
# 35           1.0       1.0   2.0         4                1           0.0
# 36           1.0       1.0   1.0         2                1          39.0
# 39           1.0       1.0   1.0         4                1           0.0
# 44           1.0       2.0   2.0         4                1           0.0
# 45           1.0       1.0   1.0         4                1          22.0
# 47           1.0       1.0   1.0         4                1           5.0
# ...          ...       ...   ...       ...              ...           ...
# 27356        1.0       1.0   1.0         4                1          15.0
# 27357        1.0       1.0   2.0         4                2          50.0
# 27358        1.0       1.0   1.0         4                1          18.0
# 27359        1.0       1.0   1.0         4                1           0.0
# 27360        1.0       1.0   1.0         4                1           0.0
# 27361        1.0       1.0   1.0         4                1           0.0
# 27362        1.0       1.0   1.0         4                2          40.0
# 27363        1.0       1.0   3.0         4                1           0.0
# 27364        1.0       1.0   1.0         4                2          10.0
# 27365        1.0       2.0   2.0         4                2          25.0
# 27366        2.0       2.0   2.0         4                1           0.0
# 27367        1.0       1.0   1.0         4                1           0.0
# 27370        1.5       1.0   3.0         4                2          35.0
# 27371        1.0       1.0   2.0         4                1           0.0
# 27372        1.0       2.0   2.0         4                2          10.0
# 27373        1.0       1.0   1.0         4                2          25.0
# 27374        1.0       1.0   1.0         4                1           0.0
# 27375        1.0       1.0   1.0         4                1           0.0
# 27376        1.0       1.0   1.0         4                1          15.0
# 27377        1.0       2.0   2.0         4                2          25.0
# 27379        1.0       2.0   2.0         4                1           0.0
# 27381        1.0       1.0   1.0         4                1           0.0
# 27382        1.0       1.0   1.0         4                2          20.0
# 27383        1.0       1.0   1.0         4                1          20.0
# 27385        1.0       2.0   2.0         4                4          25.0
# 27386        1.0       1.0   1.0         4                2          25.0
# 27388        1.0       1.0   1.0         4                1           0.0
# 27389        1.0       2.0   3.0         4                4          10.0
# 27390        1.0       1.0   1.0         4                1          10.0
# 27391        1.0       1.0   1.0         4                1           0.0
#
#        minimum_nights  maximum_nights  calendar_updated  availability_365  \
# 0                   2              13                18               322
# 2                   2              29                33               227
# 3                   9              29                12               274
# 4                   0             134                13               365
# 5                   1             115                33               287
# 8                   0             134                34               274
# 9                   3              29                17               335
# 12                  2             115                12               365
# 13                  0             134                13               364
# 14                 17             134                32               365
# 15                  1              13                18               339
# 16                  4              29                24               365
# 17                  0             134                24               365
# 18                  6              30                27               365
# 19                  0             134                32               349
# 20                  1             134                13               123
# 21                  1             134                16               191
# 22                  0             134                19               336
# 24                  1               6                32               332
# 27388                    10.0                  9.0                   0  139.0
# 27389                     9.0                  8.0                  14   99.0
# 27390                     9.0                 10.0                   6   55.0
# 27391                    10.0                 10.0                   1  110.0
#
#        distance_to_subway
# 0                0.004357
# 2                0.003158
# 3                0.001366
# 4                0.004242
# 5                0.001283
# 8                0.004388
# 9                0.008896
# 12               0.003813
# 13               0.005610
# 14               0.000836
# 15               0.002006
# 16               0.001819
# 17               0.002284
# 18               0.006981
# 19               0.001313
# 20               0.001464
# 21               0.004712
# 22               0.001454
# 24               0.005965
# 26               0.003724
# 28               0.004048
# 30               0.001408
# 32               0.000763
# 33               0.003706
# 35               0.003412
# 36               0.003040
# 39               0.003091
# 44               0.015427
# 45               0.000773
# 47               0.002415
# ...                   ...
# 27356            0.004342
# 27357            0.003278
# 27358            0.005681
# 27359            0.001842
# 27360            0.002560
# 27361            0.002951
# 27362            0.003505
# 27363            0.000598
# 27364            0.005821
# 27365            0.005898
# 27366            0.009046
# 27367            0.005299
# 27370            0.000960
# 27371            0.003422
# 27372            0.004342
# 27373            0.002047
# 27374            0.004728
# 27375            0.003017
# 27376            0.001291
# 27377            0.002684
# 27379            0.007410
# 27381            0.005016
# 27382            0.003878
# 27383            0.001111
# 27385            0.008685
# 27386            0.003454
# 27388            0.001231
# 27389            0.057929
# 27390            0.004373
# 27391            0.003861
#
# [16446 rows x 33 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(new_x.drop('price', axis = 1), new_x.price, test_size=0.2, random_state = 41)

# %% [markdown]
# ### Baseline OLS Model

# %%
linreg = LinReg()
linreg.fit(X_train,np.log(Y_train))
training_set_score = linreg.score(X_test,np.log(Y_test))
print 'The R^2 score on our training data is: ' + str(round(training_set_score,3))
# Out:
# The R^2 score on our training data is: 0.698

# %%
# stores the coefficient values of the predictors
#coefficient_values = np.array(linreg.coef_)

# stores the names of the variables
#variable_names = X_train.columns.values

# creates table storing the coefficient values and variable names
#coef_matrix = pd.DataFrame({'CoefValues':coefficient_values, 'VarName': variable_names, 'AbsCoef': abs(coefficient_values)})

# %% [markdown]
# Below is a table that contains the sorted coefficient values for each variable that we decided to include.

# %%
#sorted_coef_matrix = coef_matrix.sort(columns='AbsCoef').drop('AbsCoef', axis=1)
#sorted_coef_matrix

# %% [markdown]
# As we can see, our three categorical features have the same weight despite their encodings – this would likely not be the case in a non-linear model and will be interesting to explore.

# %% [markdown]
# ### Ridge Model (Tuned)

# %%
lambdas = 10.**np.array([-4, -3, -2, -1, 0, 1, 2, 3, 4])

#Perform Ridge regression using expanded set of predictors, 
#choose best regularization parameter lambda using 5-fold x-validation
ridge = RidgeCV(alphas=lambdas, fit_intercept=False, normalize=True, cv=5)
ridge.fit(X_train, Y_train)
ridge.score(X_test, Y_test)
# Out:
# 0.53865642276731385

# %% [markdown]
# ### Baseline Lasso Model (Tuned)

# %%
#Perform Lasso regression using expanded set of predictors, 
#choose best regularization parameter lambda using 5-fold x-validation
lasso = LassoCV(alphas=lambdas, tol=0.01, fit_intercept=False, normalize=True, cv=5)
lasso.fit(X_train, np.log(Y_train))
lasso.score(X_test, np.log(Y_test))
# Out:
# 0.65980246746806825

# %% [markdown]
# ### Random Forest Regressor

# %%
rf = RandomForestRegressor(n_estimators = 20)
rf.fit(X_train, np.log(Y_train))
rf.score(X_test, np.log(Y_test))
# Out:
# 0.75086110418864815

# %%
### Random Forest Regressor After Tuning with GridSearchCV

# %%
n_est = 20

tuned_parameters = {
    "n_estimators": [ n_est ]
}

rf_tuned = GridSearchCV(rf, cv=3, param_grid=tuned_parameters)
preds = rf_tuned.fit(X_train, np.log(Y_train))
best = rf_tuned.best_estimator_ 
rf_tuned.score(X_test, np.log(Y_test))
# Out:
# 0.74977958265857092

# %% [markdown]
# ### Ada Boost Regressor

# %%
ada = AdaBoostRegressor(base_estimator=rf_tuned, n_estimators=10)
ada.fit(X_train, np.log(Y_train))
ada.score(X_test, np.log(Y_test))
# Out:
# 0.76639282236750272

# %% [markdown]
# ### Ada Boost Regressor After Tuning with GridSearchCV

# %%
n_est = 10

tuned_parameters = {
    "base_estimator": [ rf_tuned ],
    "n_estimators": [ n_est ],
    "learning_rate": [ 0.01 ],
    "loss" : [ 'linear' ]
}

clf = GridSearchCV(ada, cv=3, param_grid=tuned_parameters)
preds = clf.fit(X_train, np.log(Y_train))
best = clf.best_estimator_ 
clf.score(X_test, np.log(Y_test))
# Out:
# 0.76228905901349209

# %% [markdown]
# ### $R^{2}$ Values Across Different Models

# %%
rs = 1
ests = [linreg, ridge, lasso, rf, ada, clf]
est_labels = np.array(['OLS','Ridge Tuned','Lasso Tuned', 'RF', 'AB (RF)', 'AB Tuned (RF)'])
errvals = np.array([0.537, 0.534, 0.522, 0.57, 0.633, 0.651])

#for e in ests:
    #e.fit(X_train, Y_train)
    #this_err = e.score(X_test, Y_test)
    #errvals = np.append(errvals, this_err)
    
pos = np.arange(errvals.shape[0])
srt = np.argsort(errvals)
plt.figure(figsize=(10,10))
plt.bar(pos, errvals[srt], align = 'center', color='#E35A5C')
plt.xticks(pos, est_labels[srt])
plt.xlabel('Estimator')
plt.ylabel('R^2 Value')
plt.title('R^2 Model Comparison')
plt.show()

# %% [markdown]
# ### Variable Importance

# %%
feature_importance = rf_tuned.best_estimator_.feature_importances_
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) - 1
pvals = feature_importance[sorted_idx]
pcols = X_train.columns[sorted_idx]
plt.figure(figsize = (8,12))
plt.barh(pos, pvals, align = 'center', color ='#E35A5C')
plt.yticks(pos, pcols)
plt.xlabel('Relative Importance')
plt.title('Predictor Importance Importance')
plt.show()

# %% [markdown]
# ### Seasonality Data

# %%
high_bucket = []
med_bucket = []
low_bucket = []

for index, item in calendar.iterrows():
    if item['listing_id'] in buckets[0]['id'].unique():
        low_bucket.append(item)
    elif item['listing_id'] in buckets[1]['id'].unique():
        med_bucket.append(item)
    elif item['listing_id'] in buckets[2]['id'].unique():
        high_bucket.append(item)

# %% [markdown]
# To observe the effect of date and seasonlity on AirBnB listing prices

# %%
calendar_dates = np.array(calendar['date'].unique())

high_bucket = pd.DataFrame(high_bucket)
med_bucket = pd.DataFrame(med_bucket)
low_bucket = pd.DataFrame(low_bucket)

high_seasonality_data = np.empty([len(calendar_dates),1])
med_seasonality_data = np.empty([len(calendar_dates),1])
low_seasonality_data = np.empty([len(calendar_dates),1])
median_seasonality_data = np.empty([len(calendar_dates),1])

index = 0

for item in calendar_dates:
    calendar_dates[index] = datetime.strptime(item,'%m/%d/%y').date()
    high_seasonality_data[index, 0] = np.mean(high_bucket['price'].loc[high_bucket['date'] == item])
    med_seasonality_data[index, 0] = np.mean(med_bucket['price'].loc[med_bucket['date'] == item])
    low_seasonality_data[index, 0] = np.mean(low_bucket['price'].loc[low_bucket['date'] == item])
    index += 1

# %%
plt.figure(figsize=(10, 7))

plt.plot(calendar_dates, high_seasonality_data, label = 'High Price Bucket', color = BNB_RED)
plt.plot(calendar_dates, med_seasonality_data, label = 'Middle Price Bucket', color = BNB_BLUE)
plt.plot(calendar_dates, low_seasonality_data, label = 'Low Price Bucket', color = BNB_LIGHT_GRAY)

plt.title('Average Nightly Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend(loc = 'best')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-b813c953e683> in <module>()
#       1 plt.figure(figsize=(10, 7))
#       2
# ----> 3 plt.plot(calendar_dates, high_seasonality_data, label = 'High Price Bucket', color = BNB_RED)
#       4 plt.plot(calendar_dates, med_seasonality_data, label = 'Middle Price Bucket', color = BNB_BLUE)
#       5 plt.plot(calendar_dates, low_seasonality_data, label = 'Low Price Bucket', color = BNB_LIGHT_GRAY)
#
# NameError: name 'calendar_dates' is not defined

# %%
plt.figure(figsize=(10, 7))

plt.plot(calendar_dates, high_seasonality_data, color ='#E35A5C')
plt.plot(calendar_dates, np.median(high_seasonality_data)*np.ones([len(high_seasonality_data),1]), color = '#850F05')

plt.title('High Price Bucket - Average Nightly Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend(loc = 'best')
plt.ylim(460,580)

plt.show()

# %%
plt.figure(figsize=(10, 7))

plt.plot(calendar_dates, med_seasonality_data, color ='#79CCCD')
plt.plot(calendar_dates, np.median(med_seasonality_data)*np.ones([len(med_seasonality_data),1]), color = '#850F05')

plt.title('Middle Price Bucket - Average Nightly Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend(loc = 'best')

plt.show()

# %%
plt.figure(figsize=(10, 7))

plt.plot(calendar_dates, low_seasonality_data, color ='#007D8C')
plt.plot(calendar_dates, np.median(low_seasonality_data)*np.ones([len(low_seasonality_data),1]), color = '#850F05')

plt.title('Low Price Bucket - Average Nightly Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend(loc = 'best')
plt.ylim(70,90)

plt.show()

# %%
test_score = best.staged_score(X_test, Y_test)
train_score = best.staged_score(X_train,Y_train)

test_score_array = []
train_score_array = []

for i in test_score:
    test_score_array.append(i)

for i in train_score:
    train_score_array.append(i)
    
plt.figure(figsize=(7, 7))

plt.scatter(range(1,11), test_score_array, label = 'Testing Data', color ='#E35A5C')
plt.scatter(range(1,11), train_score_array, label = 'Training Data', color ='#79CCCD')
plt.title('Performance Over Boosting Iterations')
plt.xlabel('Boosting Iterations')
plt.ylabel('R^2')
plt.legend(loc = 'best')

plt.show()

# %% [raw]
# ran
